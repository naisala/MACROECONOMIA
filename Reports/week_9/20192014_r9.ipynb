# %% [markdown]
# # <center> REPORT 9 <center>

# %% [markdown]
# Mariana Naiara Sosa Larriega - 20192014

# %% [markdown]
# ## PART 1: Reading Section

# %% [markdown]
# ### Innovating Monetary Policy after the 2008 crisis

# %% [markdown]
# The author deals with his research on the global economic crisis of 2008-2009, since as a result of it innovations have been incorporated into monetary policy to counteract the crisis, especially seeking to go beyond the traditional model of aggregate supply and demand of a closed economy modeling unconventional monetary policy. It focuses on what is probably the heart of the world economy: the United States, where monetary policy was changed in the hands of the Federal Reserve (FED) to deal with the crisis using the traditional instrument, the interest rate, and two other non-traditional instruments, the announcement about the future trajectory of the short-term interest rate and direct intervention (purchase) in the long-term bond market.
#
# Knowing that science is progress implies not ignoring the events of the past. Perhaps the main contribution of this research is to bring to the discussion a reevaluation of old methods to explain the current situation. It demonstrates the usefulness of past models to adapt to current crisis contexts, this is achieved mainly due to experience, because it allows the author to evaluate the results of the implementation of said models in their time. For this case, the general theory of Keynes was used, which involves unconventional instruments, the postulates of James Tobin thought in the context of the crisis of the Great Depression on the need for the intervention of the monetary authority in the long-term debt markets to accelerating the way out of the crisis and, finally, the IS-LM model proposed by Hicks, a model in which Keynes's ideas about encouraging investment with low interest rates are mathematized.
#
# The weakness of the paper that stands out the most is of a theoretical nature. If we understand science as practice, we cannot remain in the field of theory, but should be put to the test, also taking into account that models are almost never exact. They are useful but provisional and even the model presented in the paper may not be suitable for contexts of future economic crises. To this is added the little depth on one of the unconventional tools adopted by the FED, which was the announcement of the future path of the interest rate, of which it is not mentioned whether or not it is finally inserted in the model that the author proposes. It also leaves open the interpretation of the use of short-term and long-term bonds, and how the interest rate affects them.
#
# The document advances in the question arguing with the use of macroeconomic formulas the validity that past models such as Keynes, Tobin and Hicks continue to maintain until today and their usefulness to explain the current situation. This is achieved through the formulation of a model that incorporates tools and methods from those past models. Emphasis is placed on the importance of this proposed model for its ability to discover the effects of fiscal policy and the adverse shock of supply. As well as mentioning the role of the FED for the issuance of bonds.
# From what the author proposes, some steps to follow can be identified. Although this model was proposed based on the effects of the 2008 world crisis, it may be possible to carry out a study on the monetary and fiscal policies applied by the economic crisis caused by the pandemic and, in addition, to evaluate whether the model of proposed by the author is applicable to this new crisis. Following this, it could also be useful as a second step to discover errors in the theory to adapt to this new context, which would be to incur learning from the error.

# %% [markdown]
# ## PART 1: Coding Section

# %% [markdown]
# **Using IS and LM equations you have to find the $Y^e$ and $r^e$. Please show all the steps you follow to arrive at the equilibrium equations**

# %% [markdown]
# The IS curve is given as:
#
# <center>$r = \frac{\beta_0}{h} - \frac{\beta_1}{h}Y$<center>

# %% [markdown]
# Where:
#
# <center>$𝛃_𝟎 = 𝐂_𝟎 + 𝐈_𝟎 + 𝐆_𝟎 + 𝐗_𝟎$  y  $𝛃_𝟏 = 𝟏 − (𝐛 − 𝐦)(𝟏 − 𝐭)$<center>

# %% [markdown]
# Also, the LM curve is given as:
#
# <center>$r = -\frac{1}{j}\frac{M^s_0}{P_0}+\frac{k}{j}Y$<center>

# %% [markdown]
# This two curves equations need to be equilized in order to find
# the equilibrium equations of $Y^e$ and $r^e$. In this exercise we see how the exogenous variables (r and Y) affect the endogenous variables.

# %% [markdown]
# 1. Equilibrium level of income: we equilize interest rates

# %% [markdown]
# <center>$-\frac{1}{j}\frac{M^s_0}{P_0}+\frac{k}{j}Y=\frac{\beta_0}{h} - \frac{\beta_1}{h}Y$<center>

# %% [markdown]
# <center>$Y^e=\frac{j\beta_0}{kh+j\beta_1}+\frac{h}{kh+j\beta_1}\frac{M^s_0}{P_0}$<center>

# %% [markdown]
# 2. Equilibrium interest rate: we equilize levels of income

# %% [markdown]
# <center>$r^e=\frac{k\beta_0}{kh+j\beta_1}-\frac{\beta_1}{kh+j\beta_1}\frac{M^s_0}{P_0}$<center>

# %% [markdown]
# Solving by any of the three methods: reduction, equalization or substitution, the values of the income and the interest rate that balance both markets are finally obtained.

# %% [markdown]
# **Simultaneous equilibrium in the goods and money markets**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending 
Xo = 2                  # Exports (given) 
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-------------------------------------------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-------------------------------------------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-------------------------------------------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-------------------------------------------------------
y_max = np.max(i)

fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="IS-LM Model", xlabel= r'Y', ylabel= r'r')

ax.plot(Y, r, "k-", label = "IS", color = "yellowgreen")
ax.plot(Y, i, "b-", label="LM", color = "firebrick")

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())  

plt.axvline(x=51.1,  ymin= 0, ymax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black", label = "E")
plt.text(50,38, 'E', fontsize = 14, color = 'black')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/4209404064.py:45: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "yellowgreen")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/4209404064.py:46: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-", label="LM", color = "firebrick")

# %% [markdown]
# ## Comparative statics

# %% [markdown]
# **What is the effect of an Increase in government spending on the equilibrium equations? Explain using intuition, Math (using differentials) and Figures.**

# %% [markdown]
# **Effect of an increase in government spending**

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending 
Xo = 2                  # Exports (given) 
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-------------------------------------------------------
Go = 65
def r_IS_G(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS_G(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_G = r_IS_G(b, m, t, Co, Io, Go, Xo, h, Y)
#-------------------------------------------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Increase in Government Spending", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "IS", color = "yellowgreen")
ax.plot(Y, r_G, "b-",  scalex = t, scaley = t, color = "khaki", linestyle='dashed', label = 'IS_G')
ax.plot(Y, i, "b-", label="LM", color = "firebrick")  

plt.axvline(x=51.1,  ymin= 0, ymax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black", label = "E")
plt.text(49,36, 'E', fontsize = 14, color = 'black')

plt.axvline(x=57,  ymin= 0, ymax= 0.57, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=41, xmin= 0, xmax= 0.57, linestyle='dashed', color = 'lightgrey')
plt.plot(57, 41, marker="o", color="olive", label = "E_g")
plt.text(55.1,46, 'E_g', fontsize = 14, color = 'olive')

plt.text(69, 20, '∆Go', fontsize=12, color='black')
plt.text(70, 16, '→', fontsize=15, color='grey')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/1959542153.py:32: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "yellowgreen")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/1959542153.py:33: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, r_G, "b-",  scalex = t, scaley = t, color = "khaki", linestyle='dashed', label = 'IS_G')
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/1959542153.py:33: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, r_G, "b-",  scalex = t, scaley = t, color = "khaki", linestyle='dashed', label = 'IS_G')
# ...

# %% [markdown]
# $\mathbf{Intuition:}$
#
# When government spending rises, aggregate demand also increases, this makes aggregate demand greater than the level of production and therefore the level of production should increase to return to equilibrium, the demand for money increases, the demand for money is greater than the real offer and therefore the interest rate must increase.
#
# <center>$G_0\uparrow \rightarrow DA\uparrow \rightarrow DA>Y \rightarrow Y\uparrow \rightarrow M^d\uparrow \rightarrow M^d > M^s \rightarrow r\uparrow$

# %% [markdown]
# $\mathbf{Math:}$

# %% [markdown]
# $\large\Delta Y^e=\frac{j\Delta G_0}{kh+j\beta_1}\large$
#
# $\large\Delta Y^e= [\frac{j}{kh+j\beta_1}] \Delta G_0>0\large$

# %% [markdown]
# $\large\Delta r^e= \frac{k\Delta G_0}{kh+j\beta_1}\large$
#
# $\large\Delta r^e= [\frac{k}{kh+j\beta_1}] \Delta G_0>0\large$

# %% [markdown]
# **What is the effect of an Increase in Money Supply on the equilibrium equations?**

# %% [markdown]
# **Effect of increase in Money Supply**

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
#NEW CHANGE 
Ms = 12500

def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)
#-----------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effect of increase in Money Supply ($M^s$)", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "IS", color = "yellowgreen")
ax.plot(Y, i, "b-", label="LM", color = "firebrick")  
ax.plot(Y, i_Ms, "b-", label="LM", linestyle='dashed', color = "lightcoral")  


plt.axvline(x=51.1,  ymin= 0, ymax= 0.57, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black", label = "E")
plt.text(49,38, 'E', fontsize = 14, color = 'black')

plt.axvline(x=58.5,  ymin= 0, ymax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=25, xmin= 0, xmax= 0.58, linestyle='dashed', color = 'lightgrey')
plt.plot(58.5, 25, marker="o", color="firebrick", label = "E_Ms")
plt.text(56, 14, 'E_Ms', fontsize = 14, color = 'firebrick')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/1471344863.py:56: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "yellowgreen")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/1471344863.py:57: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-", label="LM", color = "firebrick")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/1471344863.py:58: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_Ms, "b-", label="LM", linestyle='dashed', color = "lightcoral")
# ...

# %% [markdown]
# $\mathbf{Intuition:}$
#
# If the money supply increases, that is, if the BCRP prints more money and there is little demand, what happens is the supply would be greater than the demand and that causes the interest rate to fall.
#
# <center>$M^o\uparrow \rightarrow M^o>M^d \rightarrow r\downarrow$
#
# As well, when interest rate falls, investment increases making agreggate demand increse too, which means agreggate demand would be greater than the production level. Finally, production level increases.
#
# <center>$r\downarrow \rightarrow I_o\uparrow \rightarrow DA>Y \rightarrow Y\uparrow$

# %% [markdown]
# $\mathbf{Math:}$

# %% [markdown]
# In production level:
#
# $\large\Delta Y^e=[\frac{h}{kh+j\beta_1}]\frac{\Delta M^s_0}{P_0}\large$
#
# $\large\Delta Y^e= [\frac{h}{kh+j\beta_1}]\frac{1}{P_0} \Delta M^s_0 > 0\large$

# %% [markdown]
# In interest rate:
#
# $\large\Delta r^e=-[\frac{\beta_1}{kh+j\beta_1}]\frac{\Delta M^s_0}{P_0}\large$
#
# $\large\Delta r^e= -[\frac{\beta_1}{kh+j\beta_1}]\frac{1}{P_0} \Delta M^s_0 < 0\large$

# %% [markdown]
# **What is the effect of a decrease in the Tax Rate ($t$) on the equilibrium equations?**

# %% [markdown]
# **Effects of a Tax Rate Reduction**

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
#NEW CHANGE
t = 0.1
def r_IS_t(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS_t(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_t = r_IS_t(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Reduction in Tax Rate (t)", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "IS", color = "yellowgreen")
ax.plot(Y, r_t, "b-",  scalex = t, scaley = t, linestyle='dashed', color = "khaki", label = 'IS_t')
ax.plot(Y, i, "b-", label="LM", color = "firebrick") 

plt.axvline(x=51.1,  ymin= 0, ymax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black", label = "E")
plt.text(48, 26, 'E', fontsize = 14, color = 'black')

plt.axvline(x=54.6,  ymin= 0, ymax= 0.55, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=37.5, xmin= 0, xmax= 0.55, linestyle='dashed', color = 'lightgrey')
plt.plot(54.5, 37.5, marker="o", color = 'olive', label = "E_t")
plt.text(52,43, 'E_t', fontsize = 14, color = 'olive')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/2016419582.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "yellowgreen")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/2016419582.py:60: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, r_t, "b-",  scalex = t, scaley = t, linestyle='dashed', color = "khaki", label = 'IS_t')
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/2016419582.py:60: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, r_t, "b-",  scalex = t, scaley = t, linestyle='dashed', color = "khaki", label = 'IS_t')
# ...

# %% [markdown]
# $\mathbf{Intuition:}$
#
# When tax rate gets reduced, disposable income increases. This means that there will be a fall in net exports and, as a consequence, the aggregate demand will be reduced (even less that production level expressed as $Y$).
#
# After all, the slope of the IS curve will decrease as well. When disposable income increases, there is more money for people to spend on goods and services. It also increases interest rate ($r$), which directly reduces investment ($I_0$).

# %% [markdown]
# <center>$t\downarrow \rightarrow Y^d\uparrow \rightarrow M\uparrow \rightarrow (X - M)\downarrow \rightarrow DA\downarrow \rightarrow DA<Y \rightarrow Y\downarrow$<center>

# %% [markdown]
# <center>$t\downarrow \rightarrow Y^d\uparrow \rightarrow r\uparrow \rightarrow I_0\downarrow$<center>

# %% [markdown]
# ## DA − OA

# %% [markdown]
# **Derive the DA equation from:**

# %% [markdown]
# The Aggregate Demand and Supply Model, DA - OA, incorporates the IS-LM model equations (with which Aggregate Demand is determined) and the Aggregate Supply equation.

# %% [markdown]
# * **Aggregate Demand (AD)**

# %% [markdown]
#    - IS: $[1-b(1-t)]Y = C_0 + I_0 + G_0 - hr$

# %% [markdown]
# - LM: $\large \frac{M^s_0}{P_0}$ $= kY - jr$

# %% [markdown]
# -  LM(B): $M^s_0 - P = kY - jr$

# %% [markdown]
# - $P$ = $\large \frac{hM^s_0 + j \beta_0}{h} - \frac{j \beta_1 + hk}{h}Y$

# %% [markdown]
# * **Aggregate Supply (AS)**
#
# <center> $P = P^e + \Theta(Y − \bar{Y})$ where $\bar{Y} = Y_f$</center>

# %% [markdown]
# $ \bar{Y} \dashrightarrow$ Potential Output
#
# $ P^e \dashrightarrow$ Expected Price Level

# %% [markdown]
# **What is the effect of an increase in government spending on the endogenous variables Y, r and P? Explain using intuition, Math (using differentials) and Figures.**

# %% [markdown]
# **AD-AS MODEL: Effects of an expansionary fiscal policy $(dG_0 > 0)$**

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
#NEW CHANGE
# Restrictive Monetary Policy: increase in Money Supply (M^s)
Ms = 6000

def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)
#-----------------------
# Expansionary Fiscal Policy: reduction in Goverment Supply (Go)
Go = 85
def r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS_Go(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_Go = r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of an expansionary Fiscal Policy $(dG_0 > 0)$", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "IS", color = "olive")
ax.plot(Y, r_Go, "k-", label = "IS'", linestyle='dashed', color = "yellowgreen")
ax.plot(Y, i, "b-", label="LM", color = "firebrick")  
ax.plot(Y, i_Ms, "b-", label="LM'", linestyle='dashed', color = "lightcoral")  

plt.axvline(x=51.2,  ymin= 0, ymax= 0.48, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=59, xmin= 0, xmax= 0.59, linestyle='dashed', color = 'lightgrey')

plt.axhline(y=32, xmin= 0, xmax= 0.51, linestyle='dashed', color = 'lightgrey')
plt.axvline(x=59,  ymin= 0, ymax= 0.63, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black")
plt.text(50,38, 'E', fontsize = 14, color = 'black')

plt.plot(59, 59.3, marker="o", color="firebrick")
plt.text(57,64, 'E_1', fontsize = 14, color = "firebrick")

plt.text(54, 0, '→', fontsize=15, color='dimgrey')
plt.text(70, 30, '→', fontsize=15, color='dimgrey')
plt.text(70, 67, '←', fontsize=15, color='dimgrey')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/963573805.py:69: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "olive")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/963573805.py:70: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, r_Go, "k-", label = "IS'", linestyle='dashed', color = "yellowgreen")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/963573805.py:70: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r_Go, "k-", label = "IS'", linestyle='dashed', color = "yellowgreen")
# ...

# %%
# AS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# AD Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
#NEW CHANGE
# Expansionary Fiscal Policy: reduction in Goverment Supply (Go)
Go = 85
def r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS_Go(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_Go = r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of an expansionary Fiscal Policy $(dG_0 > 0)$", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "AD", color = "olive")
ax.plot(Y, r_Go, "k-", label = "AD'", linestyle='dashed', color = "yellowgreen")
ax.plot(Y, i, "b-", label="AS", color = "firebrick")  

plt.axvline(x=51.2,  ymin= 0, ymax= 0.48, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.51, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black")
plt.text(50,38, 'E', fontsize = 14, color = 'black')

#E_1
plt.axhline(y=53, xmin= 0, xmax= 0.65, linestyle='dashed', color = 'lightgrey')
plt.axvline(x=65,  ymin= 0, ymax= 0.60, linestyle='dashed', color = 'lightgrey')
plt.plot(65, 53, marker="o", color="firebrick")
plt.text(63,60, 'E_1', fontsize = 14, color = "firebrick")

plt.text(57, 0, '→', fontsize=15, color='dimgrey')
plt.text(70, 30, '→', fontsize=15, color='dimgrey')
plt.text(70, 52, '↖', fontsize=15, color='dimgrey')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/1775984109.py:60: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "AD", color = "olive")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/1775984109.py:61: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, r_Go, "k-", label = "AD'", linestyle='dashed', color = "yellowgreen")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/1775984109.py:61: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r_Go, "k-", label = "AD'", linestyle='dashed', color = "yellowgreen")
# ...

# %% [markdown]
# $\mathbf{Intuition:}$

# %% [markdown]
# An expansionary Fiscal Policy tries to boost the economy, but increasing the price level is not beneficial, it only causes inflation. So when Government spending ($G_0$) increases, the Agreggate demand ($AD$) does too, which means aggregate demand becomes greater than the level of production ($Y$), so production also increases.
#
# <center>$G\uparrow \rightarrow AD\uparrow \rightarrow AD>Y \rightarrow Y\uparrow$<center>

# %% [markdown]
# In the Aggregate Supply the deviation is increasing in ($Y-\bar{Y}$), so $P$ rises.
#
# <center>$Y\uparrow \rightarrow (Y-\bar{Y})\uparrow \rightarrow P\uparrow$<center>

# %% [markdown]
# $\mathbf{Math:}$

# %% [markdown]
# - $\frac{dY}{dG_0} = \frac{-j}{|A|} > 0$
#
# - $\frac{dr}{dG_0} = \frac{-k+\frac{\Theta M^s_0}{P^2_0}}{|A|} > 0$
#
#
# - $\frac{dP}{dG_0} = \frac{-\Theta}{|A|} > 0$

# %% [markdown]
# **What is the effect of a decrease in money supply on the endogenous variables Y, r and P? Explain using intuition, Math (using differentials) and Figures.**

# %% [markdown]
# **AG-AS MODEL: Effects of a Contractionary Monetary Policy $(dM^s_0 < 0)$**

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
#NEW CHANGE
# Restrictive Monetary Policy: increase in Money Supply (M^s)
Ms = 4000

def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)
#-----------------------
# Restrictive Monetary Policy: increase in Money Supply (M^s) 2
# LM Curve
Y_size1 = 100

k1 = 15                # Transaction money demand
j1 = 10                # Speculation money demand
Ms1 = 500             # Nominal money supply 2
P1  = 20                # Price level

Y1 = np.arange(Y_size)


def i_LM_Ms1( k1, j1, Ms1, P1, Y1):
    i_LM1 = (-Ms1/P1)/j1 + k1/j1*Y1
    return i_LM1

i_Ms1 = i_LM_Ms1( k1, j1, Ms1, P1, Y1)
#-----------------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of a Contractionary Monetary Policy $(dM^s_0 < 0)$", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "IS", color = "olive")
ax.plot(Y, i, "b-", label="LM", color = "firebrick")  
ax.plot(Y, i_Ms, "b-", label="LM'", linestyle='dashed', color = "indianred")  
ax.plot(Y1, i_Ms1, "b-", label="LM2", linestyle=':', color = "indianred") 

#E
plt.axvline(x=51.2,  ymin= 0, ymax= 0.40, linestyle='dashed', color = 'lightgrey') #VERTICAL
plt.axhline(y=32, xmin= 0, xmax= 0.51, linestyle='dashed', color = 'lightgrey')    #HORIZONTAL
plt.plot(51, 32, marker="o", color="black")
plt.text(50,38, 'E', fontsize = 14, color = 'black')

#E_1
plt.axvline(x=34,  ymin= 0, ymax= 0.50, linestyle='dashed', color = 'lightgrey') #VERTICAL
plt.axhline(y=48, xmin= 0, xmax= 0.36, linestyle='dashed', color = 'lightgrey')  #HORIZONTAL
plt.plot(34, 49, marker="o", color="firebrick")
plt.text(32,55, 'E_1', fontsize = 14, color = "firebrick")

#E_2
plt.axvline(x=41,  ymin= 0, ymax= 0.46, linestyle='dashed', color = 'lightgrey') #VERTICAL
plt.axhline(y=41, xmin= 0, xmax= 0.42, linestyle='dashed', color = 'lightgrey')  #HORIZONTAL
plt.plot(41, 43, marker="o", color="firebrick")
plt.text(39,50, 'E_2', fontsize = 14, color = "firebrick")

plt.text(54, 0, '→', fontsize=15, color='dimgrey')
plt.text(70, 95, '→', fontsize=15, color='dimgrey')
plt.text(50, 67, '<-----------------', fontsize=15, color='dimgrey')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/2890790628.py:75: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "olive")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/2890790628.py:76: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-", label="LM", color = "firebrick")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/2890790628.py:77: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_Ms, "b-", label="LM'", linestyle='dashed', color = "indianred")
# ...

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
#NEW CHANGE
# Restrictive Monetary Policy: increase in Money Supply (M^s)
Ms = 6000

def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)
#-----------------------
# Expansionary Fiscal Policy: reduction in Goverment Supply (Go)
Go = 25
def r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS_Go(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_Go = r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of a Contractionary Monetary Policy $(dM^s_0 < 0)$", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "AD", color = "olive")
ax.plot(Y, r_Go, "k-", label = "AD'", linestyle='dashed', color = "yellowgreen")
ax.plot(Y, i, "b-", label="AS", color = "firebrick")  

#E
plt.axvline(x=51.2,  ymin= 0, ymax= 0.51, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.51, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black")
plt.text(50,38, 'E', fontsize = 14, color = 'black')

#E_1
plt.axvline(x=41,  ymin= 0, ymax= 0.43, linestyle='dashed', color = 'lightgrey') #VERTICAL
plt.axhline(y=17.5, xmin= 0, xmax= 0.42, linestyle='dashed', color = 'lightgrey') #HORIZONTAL
plt.plot(41, 17, marker="o", color="firebrick")
plt.text(38.5,22, 'E_1', fontsize = 14, color = "firebrick")

plt.text(45, -20, '←', fontsize=15, color='dimgrey')
plt.text(58, 10, '←', fontsize=15, color='dimgrey')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/3669441787.py:69: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "AD", color = "olive")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/3669441787.py:70: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, r_Go, "k-", label = "AD'", linestyle='dashed', color = "yellowgreen")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/3669441787.py:70: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r_Go, "k-", label = "AD'", linestyle='dashed', color = "yellowgreen")
# ...

# %% [markdown]
# $\mathbf{Intuition:}$

# %% [markdown]
# If the quantity of money (money supply) is reduced, it affects aggregate demand (AD). Aggregate demand contracts and the intercept with AS also. The real supply of money is less than the demand for money, causing the interest rate to increase, investment is frightened away, aggregate demand becomes less than the level of production (Y) and finally the product decreases.
#
# <center>$M^s_0\downarrow \rightarrow \frac{M^s}{P}<M^d \rightarrow r\uparrow$<center>

# %% [markdown]
# <center> $r\uparrow \rightarrow I\downarrow \rightarrow AD\downarrow \rightarrow AD<Y \rightarrow Y\downarrow$<center>

# %% [markdown]
# <center>$Y\downarrow \rightarrow (Y-\bar{Y})\downarrow \rightarrow P\downarrow$<center>

# %% [markdown]
# $\mathbf{Math:}$

# %% [markdown]
# - $\frac{dY}{dM^s_0} = \frac{-h}{|A|P_0} < 0$
#
# - $\frac{dr}{dM^s_0} = \frac{1-b(1-t)}{|A|P_0} > 0$
#
#
# - $\frac{dP}{dM^s_0} = \frac{-\Theta h}{|A|P_0} < 0$

# %% [markdown]
# **What is the effect of an increase in the expected prices on the endogenous variables Y, r and P? Explain using intuition, Math (using differentials) and Figures.**

# %% [markdown]
# **Expectations shock: Effects of an increase in the expected price $(dP^e>0)$**

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
# Expansionary Fiscal Policy: reduction in Goverment Supply (Go)
Go = 85
def r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS_Go(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_Go = r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of an increase in the expected price $(dP^e>0)$", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "IS", color = "olive")
ax.plot(Y, i, "b-", label="LM", color = "firebrick")  
ax.plot(Y, i_Ms, "b-", label="LM'", linestyle='dashed', color = "lightcoral")  

#E
plt.axvline(x=51.2,  ymin= 0, ymax= 0.48, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.49, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black")
plt.text(50,38, 'E', fontsize = 14, color = 'black')

#E_1
plt.axvline(x=45,  ymin= 0, ymax= 0.50, linestyle='dashed', color = 'lightgrey') #VERTICAL
plt.axhline(y=38, xmin= 0, xmax= 0.45, linestyle='dashed', color = 'lightgrey') #HORIZONTAL
plt.plot(45, 38, marker="o", color="firebrick")
plt.text(43,43, 'E_1', fontsize = 14, color = "firebrick")

plt.text(70, 67, '←', fontsize=15, color='dimgrey')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/2200147628.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "olive")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/2200147628.py:60: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-", label="LM", color = "firebrick")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/2200147628.py:61: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_Ms, "b-", label="LM'", linestyle='dashed', color = "lightcoral")
# ...

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
# Expansionary Fiscal Policy: reduction in Goverment Supply (Go)
Go = 85
def r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS_Go(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_Go = r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of an increase in the expected price $(dP^e>0)$", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "AD", color = "olive")
ax.plot(Y, i, "b-", label="AS", color = "firebrick")  
ax.plot(Y, i_Ms, "b-", label="AS'", linestyle='dashed', color = "lightcoral")  

#E
plt.axvline(x=51.2,  ymin= 0, ymax= 0.48, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.49, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black")
plt.text(50,38, 'E', fontsize = 14, color = 'black')

#E_1
plt.axvline(x=45,  ymin= 0, ymax= 0.50, linestyle='dashed', color = 'lightgrey') #VERTICAL
plt.axhline(y=38, xmin= 0, xmax= 0.45, linestyle='dashed', color = 'lightgrey') #HORIZONTAL
plt.plot(45, 38, marker="o", color="firebrick")
plt.text(43,43, 'E_1', fontsize = 14, color = "firebrick")

plt.text(70, 67, '←', fontsize=15, color='dimgrey')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/2499205345.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "AD", color = "olive")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/2499205345.py:60: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-", label="AS", color = "firebrick")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/2499205345.py:61: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_Ms, "b-", label="AS'", linestyle='dashed', color = "lightcoral")
# ...

# %% [markdown]
# $\mathbf{Intuition:}$

# %% [markdown]
# If the prices start to increase, the price level will do it as well. It directly affects the Monetary Market because the money demand will decrease, so interest rate will have to increase. In this case, investment is being frightened away. Also, aggregate demand deacreses when government spending gets reduced, so aggregate demand is lower than production level. This automatically causes the production level to also be reduced.
#
# <center> $P^e\uparrow \rightarrow P\uparrow$<center>

# %% [markdown]
# <center> $P\uparrow \rightarrow M^o\downarrow \rightarrow M^o<M^s_0 \rightarrow r\uparrow \rightarrow I_0\downarrow \rightarrow AD\downarrow \rightarrow AD<Y \rightarrow Y\downarrow$<center>

# %% [markdown]
# $\mathbf{Math:}$

# %% [markdown]
# - $\frac{dY}{dP^e} = \frac{-hM^s_0}{|A|P^2_0} < 0$
#
#
# - $\frac{dr}{dP^e} = \frac{-(1-b(1-t))M^s_0}{|A|P^2_0} > 0$
#
#
# - $\frac{dP}{dP^e} = \frac{-j(1-b(1-t))-hk}{|A|} > 0$

# %% [markdown]
# **What is the effect of an increase in the potential product on the endogenous variables Y, r and P? Explain using intuition, Math (using differentials) and Figures.**

# %% [markdown]
# **Supply Shock: Effects of an Increase in Potential Output $(d\bar{Y}>0)$**

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
#NEW CHANGE 
Ms = 12500

def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)
#-----------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of an Increase in Potential Output $(dY>0)$", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "IS", color = "yellowgreen")
ax.plot(Y, i, "b-", label="LM", color = "firebrick")  
ax.plot(Y, i_Ms, "b-", label="LM'", linestyle='dashed', color = "lightcoral")  


plt.axvline(x=51.1,  ymin= 0, ymax= 0.57, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black")
plt.text(49,38, 'E', fontsize = 14, color = 'black')

plt.axvline(x=58.5,  ymin= 0, ymax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=25, xmin= 0, xmax= 0.58, linestyle='dashed', color = 'lightgrey')
plt.plot(58.5, 25, marker="o", color="firebrick")
plt.text(56, 14, 'E_1', fontsize = 14, color = 'firebrick')

plt.text(65, 45, '→', fontsize=25, color='dimgrey')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/3790784608.py:56: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "yellowgreen")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/3790784608.py:57: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-", label="LM", color = "firebrick")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/3790784608.py:58: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_Ms, "b-", label="LM'", linestyle='dashed', color = "lightcoral")
# ...

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
#NEW CHANGE 
Ms = 12500

def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)
#-----------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of an Increase in Potential Output $(dY>0)$", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "AD", color = "yellowgreen")
ax.plot(Y, i, "b-", label="AS", color = "firebrick")  
ax.plot(Y, i_Ms, "b-", label="AS'", linestyle='dashed', color = "lightcoral")  


plt.axvline(x=51.1,  ymin= 0, ymax= 0.57, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black")
plt.text(49,38, 'E', fontsize = 14, color = 'black')

plt.axvline(x=58.5,  ymin= 0, ymax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=25, xmin= 0, xmax= 0.58, linestyle='dashed', color = 'lightgrey')
plt.plot(58.5, 25, marker="o", color="firebrick")
plt.text(56, 14, 'E_1', fontsize = 14, color = 'firebrick')

plt.text(65, 45, '→', fontsize=25, color='dimgrey')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/3176250716.py:56: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "AD", color = "yellowgreen")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/3176250716.py:57: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-", label="AS", color = "firebrick")
# C:\Users\HP\AppData\Local\Temp/ipykernel_7948/3176250716.py:58: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_Ms, "b-", label="AS'", linestyle='dashed', color = "lightcoral")
# ...

# %% [markdown]
# $\mathbf{Intuition:}$

# %% [markdown]
# An increase in the potential product causes the opposite effect on the price level, and this directly affects the money demand, which will increase so that interest rate needs to decrease. This is positive for the investment because will get increased. On the other hand, the aggregate demand will expand, even more than the production level, at it will make the product to increase.

# %% [markdown]
# <center> $P\downarrow \rightarrow M^o\uparrow \rightarrow M^o>M^s_0 \rightarrow r\downarrow \rightarrow I_0\uparrow \rightarrow AD\uparrow \rightarrow AD>Y \rightarrow Y\uparrow$<center>

# %% [markdown]
# <center>$\bar{Y}\uparrow \rightarrow P\downarrow$<center>

# %% [markdown]
# $\mathbf{Math:}$

# %% [markdown]
# - $\frac{dY}{d\bar{Y}} = \frac{-\Theta h M^s_0}{|A|P^2_0} > 0$
#
#
# - $\frac{dr}{d\bar{Y}} = \frac{\Theta j(1-b(1-t))+\Theta hk}{|A|} < 0$
#
#
# - $\frac{dP}{d\bar{Y}} = \frac{\Theta(1-b(1-t))M^s_0}{|A|P^2_0} < 0$
