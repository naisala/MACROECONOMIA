# %% [markdown]
# # <center> REPORT 8 </span> <center>

# %% [markdown]
# Mariana Naiara Sosa Larriega - 20192014

# %% [markdown]
# ## PART 1: Reading Section
# ### Macroeconomic explanations on the effects of the quarantine by COVID-19

# %% [markdown]
# The article formulates a macroeconomic model as a result of the COVID-19 pandemic and asks if it is capable of reproducing the impact of the quarantine in a two-sector economy: sector 1, the one directly affected by the quarantine and which encompasses the hotels, restaurants, airlines, etc.; while sector 2, the one indirectly affected, is characterized by the production of food and essential goods and services. Furthermore, both sectors are interrelated because workers consume goods from both.
#
# One of the strengths of this research is the proposed model. Its structure based on the division of an economy into two sectors serves as a template not only for health crises but also for other types of crises that may occur in the future, one of the most common in Peru being natural disasters such as the "Fenómeno del Niño". It is also important the fact that the text proposes in its conclusions the following steps to advance in the future by encouraging the development of public policies designed in a combination of health policy that also encompasses economics.
#
# Within the weaknesses, it would have been important if the authors had introduced the issue of the elasticity of certain products to explain the sensitivity of sector 1 compared to sector 2. In addition, during the quarantine and due to COVID-19 there were elastic goods that became be inelastic and, therefore, affected the composition of goods in both sectors. Like alcohol or masks, which have become essential goods. Likewise, the authors assume for their equations that the actors are based on the previous prices to make a decision because their incomes fell. However, that thesis was not adjusted to what was happening during the pandemic. Far from reducing their consumption, the actors rushed to buy basic necessities en masse, including toilet paper, a collective euphoria triggered by the crisis. This is where the concept of rational expectations proposed by Robert Lucas would be introduced, that when actors make economic decisions in the present they are doing so thinking about the future and not the past.
#
# The study of the economic problems triggered by the quarantine shows, by comparing two exercises, what were the effects produced on the level of production and the level of prices. This comparative proposal ended up describing effects that were very similar to reality, specifically the second exercise was the most realistic, it was the one that contrasts best with the scenario during the pandemic and the one that best describes the economic recovery, where the powerful credit policy was responsible for GDP recovery in the real scenario.
#
# Finally, since the investigation lays the foundations for the impact of the COVID-19 crisis and its containment tool, the quarantine, on the Peruvian economy. The next step would be to investigate how the measure of the impact on people's income varies according to their social status. This encompasses variables such as social class, gender, region, ethnicity, age, among others. In fact, some research of this nature has been carried out by the GRADE (Group of Analysis for Development) where some of them were written by proffesor Jaramillo, but taking into account only one of these variables separately. In parallel, some research could also be carried out on the effects of the quarantine on the formal and informal economy in Peru, taking into account the large percentage of informality present in the country.

# %% [markdown]
# ## PART 1: Coding Section

# %% [markdown]
# **Derive mathematically the equilibrium in the IS-LM model. You have to find the equilibrium equations of $Y^e$ and $r^e$.**

# %% [markdown]
# The IS curve is given as:
#
# <center>$r = \frac{\beta_0}{h} - \frac{\beta_1}{h}Y$<center>

# %% [markdown]
# Where:
#
# <center>$𝛃_𝟎 = 𝐂_𝟎 + 𝐈_𝟎 + 𝐆_𝟎 + 𝐗_𝟎$  y  $𝛃_𝟏 = 𝟏 − (𝐛 − 𝐦)(𝟏 − 𝐭)$<center>

# %% [markdown]
# Also, the LM curve is given as:
#
# <center>$r = -\frac{1}{j}\frac{M^s_0}{P_0}+\frac{k}{j}Y$<center>

# %% [markdown]
# This two curves equations need to be equilized in order to find
# the equilibrium equations of $Y^e$ and $r^e$. In this exercise we see how the exogenous variables (r and Y) affect the endogenous variables.

# %% [markdown]
# 1. Equilibrium level of income: we equilize interest rates

# %% [markdown]
# <center>$-\frac{1}{j}\frac{M^s_0}{P_0}+\frac{k}{j}Y=\frac{\beta_0}{h} - \frac{\beta_1}{h}Y$<center>

# %% [markdown]
# <center>$Y^e=\frac{j\beta_0}{kh+j\beta_1}+\frac{h}{kh+j\beta_1}\frac{M^s_0}{P_0}$<center>

# %% [markdown]
# 2. Equilibrium interest rate: we equilize levels of income

# %% [markdown]
# <center>$r^e=\frac{k\beta_0}{kh+j\beta_1}-\frac{\beta_1}{kh+j\beta_1}\frac{M^s_0}{P_0}$<center>

# %% [markdown]
# Solving by any of the three methods: reduction, equalization or substitution, the values of the income and the interest rate that balance both markets are finally obtained.

# %% [markdown]
# **Replicate, explain with math and intuition the next figure:** Simultaneous equilibrium in the goods and money markets

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 2.6                 # Taxes
C0 = 20                 # Autonomous consumption
I0 = 10                 # Investment intercept (when i = 0)
G0 = 50                 # Government spending
X0 = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i
Y = np.arange(Y_size)   # Array values of Y

def r_IS(b, m, t, C0, I0, G, X0, h, Y):
    r_IS = (C0 + I0 + G0 + X0 - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, C0, I0, G0, X0, h, r):
    Y_IS = (C0 + I0 + G0 + X0 - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, C0, I0, G0, X0, h, Y)

def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)

y_max = np.max(i)

fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Simultaneous equilibrium in the goods and money markets", xlabel= r'Y', ylabel= r'r')

ax.plot(Y, r, "k-", label = "IS", color = "red")
ax.plot(Y, i, "b-", label="LM", color = "blue")

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())  

plt.axvline(x=51.1,  ymin= 0, ymax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=15, xmin= 0, xmax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 15, marker="o", color="black", label = "E")
plt.text(50,18, 'E', fontsize = 14, color = 'black')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/915253894.py:34: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "red")
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/915253894.py:35: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-", label="LM", color = "blue")

# %% [markdown]
# The point E ($E=Y_0, r_0$) represents the point of intersection where both markets are in equilibrium, there is no excess demand or supply in both the money market and the goods market.

# %% [markdown]
# **Fiscal Policy**
#
# IS Curve: If autonomous spending rises ($G_0$), aggregate demand increases ($DA$), this is greater than the level of production and therefore, Y rises.
# <center>$G_0\uparrow \rightarrow DA\uparrow \rightarrow DA>Y \rightarrow Y\uparrow$
#
# LM Curve: If the level of production rises ($Y$), the demand for money rises ($M^d$), this makes it greater than the supply ($M^d > \frac{M^s}{P}$) and therefore the interest rate (price of money = $r$) increases.
# <center>$Y\uparrow \rightarrow M^d\uparrow \rightarrow M^d > \frac{M^s}{P} \rightarrow r\uparrow$

# %% [markdown]
# **Expressed mathematically:**
#
# $\Delta Y= [\frac{j}{kh+j\beta_1}] \Delta G_0>0$
#
# $\Delta r= [\frac{k}{kh+j\beta_1}] \Delta G_0>0$

# %% [markdown]
# **Replicate, explain with math and intuition the next figure:** Effect of an increase in government spending

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 2.6                 # Taxes
C0 = 20                 # Autonomous consumption
I0 = 10                 # Investment intercept (when i = 0)
G0 = 65                 # Government spending
X0 = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i
Y = np.arange(Y_size)   # Array values of Y

def r_IS_G(b, m, t, C0, I0, G0, X0, h, Y):
    r_IS = (C0 + I0 + G0 + X0 - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS_G(b, m, t, C0, I0, G0, X0, h, r):
    Y_IS = (C0 + I0 + G0 + X0 - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_G = r_IS_G(b, m, t, C0, I0, G0, X0, h, Y)

i = i_LM( k, j, Ms, P, Y)

y_max = np.max(i)

y_max = np.max(r)
x_max = Y_IS(b, m, t, C0, I0, G0, X0, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Increase in Government Spending", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "IS", color = "red")
ax.plot(Y, r_G, "b-",  scalex = t, scaley = t, linestyle = 'dashed', color = "red", label = 'IS_G')
ax.plot(Y, i, "b-", label="LM", color = "blue")  

plt.axvline(x=51.1,  ymin= 0, ymax= 0.49, linestyle = 'dashed', color = 'lightgrey')
plt.axhline(y=15, xmin= 0, xmax= 0.52, linestyle = 'dashed', color = 'lightgrey')
plt.plot(51, 15, marker="o", color="black", label = "E")
plt.text(50,18, 'E', fontsize = 14, color = 'black')

plt.axvline(x=57,  ymin= 0, ymax= 0.54, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=23, xmin= 0, xmax= 0.57, linestyle='dashed', color = 'lightgrey')
plt.plot(57, 23, marker="o", color="red", label = "Eg")
plt.text(55.1,27, 'Eg', fontsize = 14, color = 'black')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/426708601.py:34: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "red")
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/426708601.py:35: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, r_G, "b-",  scalex = t, scaley = t, linestyle = 'dashed', color = "red", label = 'IS_G')
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/426708601.py:35: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, r_G, "b-",  scalex = t, scaley = t, linestyle = 'dashed', color = "red", label = 'IS_G')
# ...

# %% [markdown]
# When government spending rises, aggregate demand also increases, this makes aggregate demand greater than the level of production and therefore the level of production should increase to return to equilibrium, the demand for money increases, the demand for money is greater than the real offer and therefore the interest rate must increase.
#
# <center>$G_0\uparrow \rightarrow DA\uparrow \rightarrow DA>Y \rightarrow Y\uparrow \rightarrow M^d\uparrow \rightarrow M^d > M^s \rightarrow r\uparrow$

# %% [markdown]
# 2.4

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
#NEW CHANGE 
Ms = 12500

def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)
#-----------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effect of increase in Money Supply ($M^s$)", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "IS", color = "red")
ax.plot(Y, i, "b-", label="LM", color = "blue")  
ax.plot(Y, i_Ms, "b-", label="LM", linestyle='dashed', color = "blue")  


plt.axvline(x=51.1,  ymin= 0, ymax= 0.57, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black", label = "E")
plt.text(49,38, 'E', fontsize = 14, color = 'black')

plt.axvline(x=58.5,  ymin= 0, ymax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=25, xmin= 0, xmax= 0.58, linestyle='dashed', color = 'lightgrey')
plt.plot(58.5, 25, marker="o", color="blue", label = "E_Ms")
plt.text(56, 14, 'E_Ms', fontsize = 14, color = 'black')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/373103716.py:56: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "red")
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/373103716.py:57: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-", label="LM", color = "blue")
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/373103716.py:58: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_Ms, "b-", label="LM", linestyle='dashed', color = "blue")
# ...

# %% [markdown]
# If the money supply increases, that is, if the BCRP prints more money and there is little demand, what happens is the supply would be greater than the demand and that causes the interest rate to fall.
#
# <center>$M^o\uparrow \rightarrow M^o>M^d \rightarrow r\downarrow$
#
# As well, when interest rate falls, investment increases making agreggate demand increse too, which means agreggate demand would be greater than the production level. Finally, production level increases.
#
# <center>$r\downarrow \rightarrow I_o\uparrow \rightarrow DA>Y \rightarrow Y\uparrow$

# %% [markdown]
# **Replicate, explain with math and intuition the next figure:** Effects of Expansionary Monetary and Restrictive Riscal Policy

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
#NEW CHANGE
#Expansionary Monetary Policy: increase in Money Supply (M^s)
Ms = 12500

def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)
#-----------------------
#Restrictive Fiscal Policy: reduction in Goverment Supply (Go)
Go = 33
def r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS_Go(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_Go = r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of Expansionary Monetary Policy and Restrictive Fiscal Policy", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "IS", color = "red")
ax.plot(Y, r_Go, "k-", label = "IS_G", linestyle='dashed', color = "red")
ax.plot(Y, i, "b-", label="LM", color = "blue")  
ax.plot(Y, i_Ms, "b-", label="LM_Ms", linestyle='dashed', color = "blue")  

plt.axvline(x=51.1,  ymin= 0, ymax= 0.57, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black", label = "E")
plt.text(49,38, 'E', fontsize = 14, color = 'black')

plt.axhline(y=14.5, xmin= 0, xmax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 14.5, marker="o", color="blue", label = "E_1")
plt.text(49,5, 'E_1', fontsize = 14, color = 'black')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/3599073882.py:69: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "red")
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/3599073882.py:70: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, r_Go, "k-", label = "IS_G", linestyle='dashed', color = "red")
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/3599073882.py:70: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r_Go, "k-", label = "IS_G", linestyle='dashed', color = "red")
# ...

# %% [markdown]
# **Expansionary Monetary Policy**
#
# With this policy, the supply of money increases, which makes it greater than the demand for money, which also causes the interest rate to fall.
#
# <center>$M^o\uparrow \rightarrow M^o>M^d \rightarrow r\downarrow$
#
# When interest rates gets reduced, it causes investment to raise as well as aggregate demand, which also makes this last to be greater than production level.
#
# <center>$r\downarrow \rightarrow I_o\uparrow \rightarrow DA\uparrow \rightarrow DA>Y \rightarrow Y\uparrow$

# %% [markdown]
# **Restrictive Fiscal Policy**
#
# If autonomous spending falls, aggregate demand falls with it, which makes the latter less than the level of production, so it also falls.
#
# <center>$G_0\downarrow \rightarrow DA\downarrow \rightarrow DA<Y \rightarrow Y\downarrow$<center>
#
# If the level of production also fell, the demand for money would also fall, that makes the demand for money less than the supply of money and finally, the interest rate must fall
#
# <center>$Y\downarrow \rightarrow M^d\downarrow \rightarrow M^d < M^o \rightarrow r\downarrow$<center>

# %% [markdown]
# **Expressed Mathematically**
#
# Expansionary Monetary Policy
#
# $\Delta Y= [\frac{h}{kh+j\beta_1}]\frac{1}{P_0} \Delta M^s_o>0$
#
# $\Delta r= [\frac{\beta_1}{kh+j\beta_1}]\frac{1}{P_0} \Delta M^s_o>0$
#
# Restrictive Fiscal Policy
#
# $\Delta Y= [\frac{j}{kh+j\beta_1}] \Delta G_0>0$
#
# $\Delta r= [\frac{k}{kh+j\beta_1}] \Delta G_0>0$

# %% [markdown]
# 2.7

# %%
# IS Curve
Y_size = 100 
b = 0.4                 # Marginal propensity to consume
m = 0.2                 # Marginal propensity to import
t = 0.9                 # Taxes
Co = 20                 # Autonomous consumption
Io = 10                 # Investment intercept (when i = 0)
Go = 50                 # Government spending
Xo = 2                  # Exports (given)
h =  1                  # Investment slope wrt to i

Y = np.arange(Y_size)   # Array values of Y
#-----------------------
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
# LM Curve
Y_size = 100

k = 15                # Transaction money demand
j = 10                # Speculation money demand
Ms = 9000             # Nominal money supply
P  = 20                # Price level

Y = np.arange(Y_size)
#-----------------------
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
#-----------------------
#NEW CHANGE
t = 0.1
def r_IS_t(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS_t(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_t = r_IS_t(b, m, t, Co, Io, Go, Xo, h, Y)
#-----------------------
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Reduction in Tax Rate (t)", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "IS", color = "blue")
ax.plot(Y, r_t, "b-",  scalex = t, scaley = t, linestyle='dashed', color = "blue", label = 'IS_t')
ax.plot(Y, i, "b-", label="LM", color = "red")  


plt.axvline(x=51.1,  ymin= 0, ymax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=32, xmin= 0, xmax= 0.52, linestyle='dashed', color = 'lightgrey')
plt.plot(51, 32, marker="o", color="black", label = "E")
plt.text(48, 26, 'E', fontsize = 14, color = 'black')

plt.axvline(x=54.6,  ymin= 0, ymax= 0.55, linestyle='dashed', color = 'lightgrey')
plt.axhline(y=37.5, xmin= 0, xmax= 0.55, linestyle='dashed', color = 'lightgrey')
plt.plot(54.5, 37.5, marker="o", color="blue", label = "E_t")
plt.text(52,43, 'E_t', fontsize = 14, color = 'black')

ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/82595435.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "blue")
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/82595435.py:60: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, r_t, "b-",  scalex = t, scaley = t, linestyle='dashed', color = "blue", label = 'IS_t')
# C:\Users\HP\AppData\Local\Temp/ipykernel_17848/82595435.py:60: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, r_t, "b-",  scalex = t, scaley = t, linestyle='dashed', color = "blue", label = 'IS_t')
# ...

# %% [markdown]
# When tax rate gets reduced, disposable income increases, which means that the slope of the IS curve will decrease as well. When disposable income increases, there is more money for people to spend on goods and services. It also increases interest rate, which directly reduces investment.
#
# <center>$t\downarrow \rightarrow Y^d\downarrow \rightarrow r\uparrow \rightarrow I_0\downarrow$<center>
